# %%
from langchain.embeddings import OpenAIEmbeddings
import faiss
from langchain.vectorstores import FAISS
from langchain.docstore import InMemoryDocstore

# Define the embedding model
embeddings_model = OpenAIEmbeddings(model="text-embedding-ada-002")

# Initialize the vectorstore
embedding_size = 1536
index = faiss.IndexFlatL2(embedding_size)
vectorstore = FAISS(embeddings_model.embed_query, index, InMemoryDocstore({}), {})

# %%
from langchain import OpenAI
from langchain.experimental import BabyAGI

# set the goal
goal = "Plan a trip to Cancun, Quintana Roo, Mexico"

# create thebabyagi agent
# If max_iterations is None, the agent may go on forever if stuck in loops
baby_agi = BabyAGI.from_llm(
    llm=OpenAI(model="text-davinci-003", temperature=0),
    vectorstore=vectorstore,
    verbose=False,
    max_iterations=3
)
response = baby_agi({"objective": goal})
# Out:
# *****TASK LIST*****
#
# 1: Make a todo list
#
# *****NEXT TASK*****
#
# 1: Make a todo list
#
# *****TASK RESULT*****
#
#
#
# 1. Research flights to Cancun
# 2. Research hotels in Cancun
# 3. Research activities to do in Cancun
# 4. Create a budget for the trip
# 5. Book flights to Cancun
# 6. Book hotel in Cancun
# 7. Book activities in Cancun
# 8. Pack for the trip
# 9. Arrange transportation to and from the airport
# 10. Enjoy your trip to Cancun!
#
# *****TASK LIST*****
#
# 2: Research transportation options in Cancun
# 3: Research currency exchange rates
# 4: Research local customs and laws
# 5: Research weather conditions in Cancun
# 6: Research local attractions
# 7: Research local shopping options
# 8: Research local nightlife
# 9: Research local medical facilities
# 10: Research local emergency services
# 11: Plan a trip to Cancun, Quintana Roo, Mexico
# 1: Research restaurants in Cancun
#
# *****NEXT TASK*****
#
# 2: Research transportation options in Cancun
#
# *****TASK RESULT*****
#
#
#
# To research transportation options in Cancun, Quintana Roo, Mexico, I would suggest looking into the following:
#
# 1. Public transportation: Cancun has a public bus system, as well as a ferry service to the nearby island of Isla Mujeres.
#
# 2. Taxis: Taxis are widely available in Cancun and can be hailed from the street or booked in advance.
#
# 3. Car rental: There are several car rental companies in Cancun, including international companies such as Hertz and Avis.
#
# 4. Private transportation: Private transportation services such as Uber and Lyft are available in Cancun.
#
# 5. Bicycles: Bicycles can be rented from several shops in Cancun.
#
# 6. Walking: Cancun is a relatively small city and many attractions can be reached on foot.
#
# I hope this information helps you plan your trip to Cancun!
#
# *****TASK LIST*****
#
# 3: Research currency exchange rates
# 4: Research local customs and laws
# 5: Research weather conditions in Cancun
# 6: Research local attractions
# 7: Research local shopping options
# 8: Research local nightlife
# 9: Research local medical facilities
# 10: Research local emergency services
# 11: Research the cost of transportation in Cancun
# 12: Research the availability of public transportation in Cancun
# 13: Research the availability of car rental services in Cancun
# 14: Research the availability of private transportation services in Cancun
# 15: Research the availability of bicycle rental services in Cancun
# 16: Research the safety of walking in Cancun
# 17: Research the cost of currency exchange in Cancun
# 18: Research the availability of medical facilities in Cancun
# 19: Research the availability of emergency services in Cancun
# 20: Research the cost of accommodations in Cancun
# 21: Research the availability of attractions in Cancun
# 22: Research the availability of shopping options in Cancun
# 23: Research the availability of nightlife in Cancun
# 24: Research the availability of
#
# *****NEXT TASK*****
#
# 3: Research currency exchange rates
#
# *****TASK RESULT*****
#
#
#
# I will research currency exchange rates for Cancun, Quintana Roo, Mexico. I will look into the current exchange rate for the Mexican Peso (MXN) to the US Dollar (USD), as well as any other currencies that may be used in Cancun. I will also research any fees associated with exchanging currency in Cancun, as well as any other information that may be useful for travelers.
#
# *****TASK ENDING*****
